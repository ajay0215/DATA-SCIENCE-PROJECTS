# %%
import numpy as np
import pandas as pd

# %%
column_names=["User_ID","upvote","downvote","comments","impressions","followers","timespent","age","gender","clan","rank"]
data=pd.DataFrame(index=range(1,10001),columns=column_names)

# %%
data.head()
# Out:
#   User_ID upvote downvote comments impressions followers timespent  age  \
# 1     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 2     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 3     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 4     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 5     NaN    NaN      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
for i in range(1,10001):
    data["User_ID"][i]=i

# %%
data.head()
# Out:
#   User_ID upvote downvote comments impressions followers timespent  age  \
# 1       1    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 2       2    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 3       3    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 4       4    NaN      NaN      NaN         NaN       NaN       NaN  NaN
# 5       5    NaN      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
import random
data["upvote"]=data["upvote"].apply(lambda x:np.random.random()*1000)

# %%
data["upvote"]=data["upvote"].apply(np.floor)

# %%
data.head()
# Out:
#   User_ID  upvote downvote comments impressions followers timespent  age  \
# 1       1   969.0      NaN      NaN         NaN       NaN       NaN  NaN
# 2       2   679.0      NaN      NaN         NaN       NaN       NaN  NaN
# 3       3   336.0      NaN      NaN         NaN       NaN       NaN  NaN
# 4       4   886.0      NaN      NaN         NaN       NaN       NaN  NaN
# 5       5    17.0      NaN      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
import random
data["downvote"]=data["downvote"].apply(lambda x:np.random.random()*1000)

# %%
data["downvote"]=data["downvote"].round(decimals=0)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote comments impressions followers timespent  age  \
# 1       1   969.0       9.0      NaN         NaN       NaN       NaN  NaN
# 2       2   679.0     767.0      NaN         NaN       NaN       NaN  NaN
# 3       3   336.0     704.0      NaN         NaN       NaN       NaN  NaN
# 4       4   886.0     273.0      NaN         NaN       NaN       NaN  NaN
# 5       5    17.0     133.0      NaN         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data.describe()
# Out:
#              upvote     downvote
# count  10000.000000  10000.00000
# mean     493.749200    498.93270
# std      289.586156    287.15122
# min        0.000000      0.00000
# 25%      245.000000    252.00000
# 50%      487.000000    498.00000
# 75%      745.250000    746.00000
# max      999.000000   1000.00000

# %%
data["comments"]=(data["upvote"]+data["downvote"])/10

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments impressions followers timespent  age  \
# 1       1   969.0       9.0      97.8         NaN       NaN       NaN  NaN
# 2       2   679.0     767.0     144.6         NaN       NaN       NaN  NaN
# 3       3   336.0     704.0     104.0         NaN       NaN       NaN  NaN
# 4       4   886.0     273.0     115.9         NaN       NaN       NaN  NaN
# 5       5    17.0     133.0      15.0         NaN       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data["impressions"]=(data["upvote"]+data["downvote"])*1.5

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions followers timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0       NaN       NaN  NaN
# 2       2   679.0     767.0     144.6       2169.0       NaN       NaN  NaN
# 3       3   336.0     704.0     104.0       1560.0       NaN       NaN  NaN
# 4       4   886.0     273.0     115.9       1738.5       NaN       NaN  NaN
# 5       5    17.0     133.0      15.0        225.0       NaN       NaN  NaN
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data["followers"]=data["impressions"]*5

# %%
data.tail()
# Out:
#       User_ID  upvote  downvote  comments  impressions  followers timespent  \
# 9996     9996   474.0     374.0      84.8       1272.0     6360.0       NaN
# 9997     9997    93.0     240.0      33.3        499.5     2497.5       NaN
# 9998     9998   230.0     605.0      83.5       1252.5     6262.5       NaN
# 9999     9999   402.0      15.0      41.7        625.5     3127.5       NaN
# 10000   10000   448.0     833.0     128.1       1921.5     9607.5       NaN
#
#        age gender clan rank
# 9996   NaN    NaN  NaN  NaN
# 9997   NaN    NaN  NaN  NaN
# 9998   NaN    NaN  NaN  NaN
# 9999   NaN    NaN  NaN  NaN
# 10000  NaN    NaN  NaN  NaN

# %%
data["age"]=data["age"].apply(lambda x:np.random.randint(20,50))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0       NaN   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0       NaN   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0       NaN   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5       NaN   37
# 5       5    17.0     133.0      15.0        225.0     1125.0       NaN   49
#
#   gender clan rank
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# 5    NaN  NaN  NaN

# %%
data["gender"]=data["gender"].apply(lambda x:np.random.randint(1,3))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0       NaN   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0       NaN   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0       NaN   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5       NaN   37
# 5       5    17.0     133.0      15.0        225.0     1125.0       NaN   49
#
#    gender clan rank
# 1       1  NaN  NaN
# 2       2  NaN  NaN
# 3       2  NaN  NaN
# 4       1  NaN  NaN
# 5       2  NaN  NaN

# %%
data["gender"].value_counts()
# Out:
# 2    5052
# 1    4948
# Name: gender, dtype: int64

# %%
data["gender"]=data["gender"].replace({1:"Male",2:"Female"})

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0       NaN   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0       NaN   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0       NaN   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5       NaN   37
# 5       5    17.0     133.0      15.0        225.0     1125.0       NaN   49
#
#    gender clan rank
# 1    Male  NaN  NaN
# 2  Female  NaN  NaN
# 3  Female  NaN  NaN
# 4    Male  NaN  NaN
# 5  Female  NaN  NaN

# %%
data["viewers"]=((data["impressions"])-(data["upvote"]+data["downvote"]))

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0       NaN   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0       NaN   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0       NaN   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5       NaN   37
# 5       5    17.0     133.0      15.0        225.0     1125.0       NaN   49
#
#    gender clan rank  viewers
# 1    Male  NaN  NaN    489.0
# 2  Female  NaN  NaN    723.0
# 3  Female  NaN  NaN    520.0
# 4    Male  NaN  NaN    579.5
# 5  Female  NaN  NaN     75.0

# %%
data["timespent"]=((data["upvote"]+data["downvote"])*15+(data["comments"]*30)+(data["viewers"]*10))

# %%
data["timespent"]=data["timespent"]/3600

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0   6.248333   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0   9.238333   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0   6.644444   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5   7.404722   37
# 5       5    17.0     133.0      15.0        225.0     1125.0   0.958333   49
#
#    gender clan rank  viewers
# 1    Male  NaN  NaN    489.0
# 2  Female  NaN  NaN    723.0
# 3  Female  NaN  NaN    520.0
# 4    Male  NaN  NaN    579.5
# 5  Female  NaN  NaN     75.0

# %%
data["clan"]=data["clan"].apply(lambda x:np.random.randint(1,14))

# %%
data["clan"].value_counts()
# Out:
# 6     803
# 7     795
# 13    795
# 8     786
# 5     781
# 9     774
# 10    766
# 2     764
# 11    757
# 1     752
# 12    748
# 3     742
# 4     737
# Name: clan, dtype: int64

# %%
data["clan"]=data["clan"].replace({1:"Technology",2:"Travel",3:"Internships",4:"Jobs",5:"Startups",6:"Trending",7:"Fashion",8:"Politics",9:"Music",10:"Bollywood",11:"Cricket",12:"News",13:"Food"})

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0   6.248333   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0   9.238333   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0   6.644444   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5   7.404722   37
# 5       5    17.0     133.0      15.0        225.0     1125.0   0.958333   49
#
#    gender      clan rank  viewers
# 1    Male     Music  NaN    489.0
# 2  Female     Music  NaN    723.0
# 3  Female      Food  NaN    520.0
# 4    Male  Politics  NaN    579.5
# 5  Female  Trending  NaN     75.0

# %%
data["clan"].value_counts()
# Out:
# Trending       803
# Food           795
# Fashion        795
# Politics       786
# Startups       781
# Music          774
# Bollywood      766
# Travel         764
# Cricket        757
# Technology     752
# News           748
# Internships    742
# Jobs           737
# Name: clan, dtype: int64

# %%
data.drop("viewers",axis=1,inplace=True)

# %%
data.head()
# Out:
#   User_ID  upvote  downvote  comments  impressions  followers  timespent  age  \
# 1       1   969.0       9.0      97.8       1467.0     7335.0   6.248333   48
# 2       2   679.0     767.0     144.6       2169.0    10845.0   9.238333   40
# 3       3   336.0     704.0     104.0       1560.0     7800.0   6.644444   22
# 4       4   886.0     273.0     115.9       1738.5     8692.5   7.404722   37
# 5       5    17.0     133.0      15.0        225.0     1125.0   0.958333   49
#
#    gender      clan rank
# 1    Male     Music  NaN
# 2  Female     Music  NaN
# 3  Female      Food  NaN
# 4    Male  Politics  NaN
# 5  Female  Trending  NaN

# %%
data.to_csv("Analytics11.csv",index=False)
